# %%
import trend
# %matplotlib widget

# %%
calibration = trend.CalibrationTrend('example_input/310-600trend_new.csv',
                                     'f_Range.csv', 
                                     'amp_range.csv', 
                                     fLOW       = 310,
                                     fHIGH      = 600,
                                     ladderDrop = -0.5,
                                     stepHeight = 0.01)

# %%
calibration.plot_trend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
calibration.sanity_check()
# Out:
# True

# %%
calibration.examine_ladder(2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
calibration.create_amp_file()
calibration.create_key_sight_file()

# %%
iteration = trend.SecondaryCalibration('example_input/vertical_shake_test_trend.csv',
                                       'example_input/vertical_ampFile.csv',
                                       'f_range.csv',
                                       'amp_range.csv')

# %%
iteration.plot_trend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
iteration.sanity_check()
# Out:
# True

# %%
iteration.correct_amplitudes()
# Out:
#      Frequency (Hz)  Amplitude (mV)
# 0                20             110
# 1                30             131
# 2                40             185
# 3                50             248
# 4                60             284
# ..              ...             ...
# 118            1920             354
# 119            1940             293
# 120            1960             237
# 121            1980             183
# 122            2000             155
#
# [123 rows x 2 columns]

# %%
iteration.create_key_sight_file()
